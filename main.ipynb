# %% [markdown]
# ### 2025-5-23

# %%
#获所有取突变数据的嵌入
# 脚本路径 esm3b路径 序列fasta路径 输出路径 tokes_per_batch大小 合并众多序列embedings后的路径

# !python /data/home/maorunzegroup/xuxiaoxian/project/baseproject/plm/esm/extract.py esm2_t36_3B_UR50D /data/home/maorunzegroup/xuxiaoxian/project/baseproject/data/mutant_seq.fasta /data/home/maorunzegroup/xuxiaoxian/project/baseproject/data/embeding/esm --toks_per_batch 512 --include mean --concatenate_dir /data/home/maorunzegroup/xuxiaoxian/project/baseproject/data/embeding
