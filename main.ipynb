# %% [markdown]
# ### 2025-5-23

# %%
#获所有取突变数据的嵌入
# 脚本路径 esm3b路径 序列fasta路径 输出路径 tokes_per_batch大小 合并众多序列embedings后的路径

# !python /data/home/maorunzegroup/xuxiaoxian/Basepro/src/plm/extract.py esm2_t36_3B_UR50D /data/home/maorunzegroup/xuxiaoxian/Basepro/data/p1450.fasta /data/home/maorunzegroup/xuxiaoxian/Basepro/output/embdeding/esm --toks_per_batch 512 --include mean --concatenate_dir /data/home/maorunzegroup/xuxiaoxian/Basepro/output/embdeding
# Out:
# Transferred model to GPU
# Read /data/home/maorunzegroup/xuxiaoxian/Basepro/data/p1450.fasta with 1 sequences
# Processing 1 of 1 batches (1 sequences)
# Device: cuda:0
# Saved representations to /data/home/maorunzegroup/xuxiaoxian/Basepro/output/embdeding/esm
# ...

# %%
torch
